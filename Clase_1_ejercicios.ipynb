# %% [markdown]
# <a href="https://colab.research.google.com/github/nhernandez446-web/PROGCOM-B/blob/main/Clase_1_ejercicios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
helado=input("Quieres helado?")
helaresta="Te lo compro"
helanegacion="No te lo compro"
if helado.lower()=="si" or helado.lower()=="sí":
  print(helaresta)
elif helado.lower()=="sipi" or helado.lower()=="sisas":
  print(helaresta)
else:
  print(helanegacion)
# Out:
# Quieres helado?si
# Te lo compro

# %%
helado=input("Quieres helado?")
helaresta="Te lo compro"
helanegacion="No te lo compro"
match helado.lower():
  case "si":print(helaresta)
  case "sí":print(helaresta)
  case "sipis":print(helaresta)
  case "sisas":print(helaresta)
  case "clarinetes":print(helaresta)
  case "seh":print(helaresta)
  case _:print(helanegacion)
# Out:
# Quieres helado?seh
# Te lo compro

# %%
Primera infancia: 0 a 5
niñez: 6 a 12
preadolecencia: 10 a 14
adolecente tarido: 15 a 19
adulto joven: 20 a 26
adulto: 25 a 59
adulto mayor: 60+

# %%
nomb=input("ingrese su nombre")
age=int(input("Bienvenido, cuantos años tienes?"))
"""
if age>=0 and age<=5:
  prinfa=True
elif age>=6 and age<=12:
  nine=True
elif age>=10 and age<=14:
  pread=True
elif age>=15 and age<=19:
  adtar=True
elif age>=20 and age<=26:
  adul=True
  Corrección
  """
if ("Usted es un niño") if edad>=6 and edad<=12, else ("usted no es un niño")
# Out:
#   File "/tmp/ipykernel_1124/2720234118.py", line 16
#     ("Usted es un niño") if edad>=6 and edad<=12, else ("usted no es un niño")
#      ^
# SyntaxError: expected 'else' after 'if' expression

# %% [markdown]
# * Calor: >26
# * Templado: 20-26
# * Frio: <20

# %%
temp=int(input("Nivel de temperatura: "))
if temp>=26: print("Hace mucha calor")
elif temp>=20 and temp<26: print("El clima es agradable")
elif temp<20 and temp>=-10:print("Hace mucho frio")
else print("brrrrr")

# %%
temp=int(input("Nivel de temperatura: "))
op3=("Hace mucho frio") if temp<20 and temp>=-10 else ("brrrrr")
op2=("El clima es agradable") if temp>=20 and temp<26 else op3
op1=("Hace mucha calor") if temp>=26 else op2
print(op1)
# Out:
# Nivel de temperatura: -12
# brrrrr

# %%
temp=int(input("Nivel de temperatura: "))
match temp:
  case temp if temp>=26: print("Hace mucha calor")
  case temp if temp>=20 and temp<26: print("El clima es agradable")
  case temp if temp<20 and temp>=-10: print("Hace mucho frio")
  case _: print ("brrrr")
  # Se puede usar una variablae igual a otra adentro de la funcion por memoria
# Out:
# Nivel de temperatura: 25
# El clima es agradable

# %%
nom=input("ingrese su nombre ")
age=int(input("Ingrese su edad "))
paso=print(f"Bienvenido, {nom}. Como tienes {age} años, puedes usar este servicio. Como podria ayudarte?") if age>=10 else ("Acceso denegado")
print(paso)
print("\n|| 1) Hallar el área de un circulo")
print("|| 2) Hallar el área de un cuadrado")
print("|| 3) Hallar el volumen de un cono")
print("|| 4) Recordatorio sobre las operaciones basicas (incompleto)")
choc=int(input("\n"))
match choc:
  case 1:
    lad1=int(input("Inserte la medida de la altura en centimetros "))
    lad2=int(input("Inserte la medida de la base en centimetros "))
    area=lad1*lad2
    cuad=("cuadrado") if lad1==lad2 else ("rectangulo")
    print(f"El área de su {cuad} es de {area} centimetros cuadrados.")
  case 2:
    r=int(input("Inserte la medida del radio de su circulo en centimetros "))
    area=(3.14)*(r**2)
    print(f"El área de su circulo es de {area} centimetros cuadrados.")
  case 3:
    r=int(input("Ingrese la medida del radio del cono en centimetros "))
    g=int(input("Ingrese la medida generatriz del cono en centimetros "))
    area=(3.14)*r*(r+g)
    print(f"El área de su cono es de {area} centimetros cuadrados.")
